# %% [markdown]
# ### This notebook contains the following operations
# * Load the US Video data with Titles/Tags/Descriptions
# * Create iterators for train, validation and test datasets
# * Run the analysis with neural network models (including RNN, CNN, and simple Linear NN)
# * Run the analysis with Machine Learning Models (logistic regression and random forest) with reduced TFIDF matrix
# * Run the analysis with Logistic Regression with Bag of Words of ngrams
# * Visualize the comparison of the performances

# %%
import data_input as data_in
import nnmodels as nnm
import mlmodels as mlm
import bow_models as bowm
import train_eval
import visualization as vis
from torchtext import data
import torch

# %% [markdown]
# ### Load Data and Define Train, Valid, and Test Sets for Video Titles/Tags/Descriptions

# %%
data_dir = r'D:\Researching Data\Youtube data\USvideos.csv' # should specify the directory for US video data
path = r'D:\Researching Data\Youtube data' # should specify the directory for all video data
MAX_VOCAB_SIZE = 25000
TRAIN_VALID_TEST_R = (0.4, 0.4, 0.2)
BATCH_SIZE = 64

# %%
new_TEXT, new_label, new_arr = data_in.load_data(data_dir, 25, "full")
# using title, tags might be problematic for CNN models (the length of sequences)

torch.backends.cudnn.deterministic = True
TEXT = data.Field(tokenize = 'spacy')
LABEL = data.LabelField(dtype = torch.float)
train_data, valid_data, test_data = data_in.build_train_test(path, new_arr, TRAIN_VALID_TEST_R, TEXT, LABEL)

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)
device = torch.device('cpu') # switch to local device 
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_iterator, valid_iterator, test_iterator = data_in.build_iterator(BATCH_SIZE, device, train_data, valid_data, test_data)
# Out:
# 7.951503700204691  percent of videos are labelled as the selected category
# the baseline precision is  7.951503700204691  in this model
# The size of train, valid and test data are 2540 2540 1271
# Number of training examples: 2539
# Number of testing examples: 1270
# Number of validation examples:2539

# %% [markdown]
# ### Run Neural Network Models

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 50
OUTPUT_DIM = 1
N_LAYERS = 2
BIDIRECTIONAL = True
DROPOUT = 0.5
N_FILTERS = 100
FILTER_SIZES = [3,4,5]
PAD_IDX = TEXT.vocab.stoi[TEXT.pad_token]

model_wordem = nnm.WordEmbAvg_2linear(INPUT_DIM, EMBEDDING_DIM, 
                                      HIDDEN_DIM, OUTPUT_DIM, PAD_IDX)
model_rnn = nnm.SimpleRNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, 
                          OUTPUT_DIM, PAD_IDX)
model_BLSTM = nnm.LSTM(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, 
                       N_LAYERS, BIDIRECTIONAL, DROPOUT, PAD_IDX)
model_GRU = nnm.GRU(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, 
                    N_LAYERS, BIDIRECTIONAL, DROPOUT, PAD_IDX)
model_CNN = nnm.CNN(INPUT_DIM, EMBEDDING_DIM, N_FILTERS, FILTER_SIZES, 
                    OUTPUT_DIM, DROPOUT, PAD_IDX)
MODEL_DICT = {"avg_embedding": model_wordem, "SimpleRNN": model_rnn,
              "BLSTM": model_BLSTM, "BGRU": model_GRU, "CNN": model_CNN}

# %%
best_models, models_perf = train_eval.compare_models(MODEL_DICT, device, train_iterator, valid_iterator, test_iterator)
train_eval.get_effective_norms(best_models, TEXT)
# Out:
# currently training the model:  avg_embedding
# Epoch 0: Dev Accuracy: 0.920703125 Dev Loss:0.21663263011723757
# Epoch 1: Dev Accuracy: 0.97109375 Dev Loss:0.08539670206373558
# Epoch 2: Dev Accuracy: 0.9619186043739318 Dev Loss:0.12650565722651663
# Epoch 3: Dev Accuracy: 0.9654342293739319 Dev Loss:0.13133197115239453
# Epoch 4: Dev Accuracy: 0.9671875 Dev Loss:0.129409638549987
# Test Loss: 0.113 | Test Acc: 96.39%
# Test Prec: nan% | Test Rec: 57.372%
# currently training the model:  SimpleRNN
# Epoch 0: Dev Accuracy: 0.920703125 Dev Loss:0.284375783149153
# Epoch 1: Dev Accuracy: 0.920703125 Dev Loss:0.27672437094151975
# Epoch 2: Dev Accuracy: 0.920703125 Dev Loss:0.27349042035639287
# Epoch 3: Dev Accuracy: 0.920703125 Dev Loss:0.27997472062706946
# Epoch 4: Dev Accuracy: 0.920703125 Dev Loss:0.2784816395491362
# Test Loss: 0.313 | Test Acc: 91.08%
# Test Prec: nan% | Test Rec: 0.000%
# currently training the model:  BLSTM
# Epoch 0: Dev Accuracy: 0.920703125 Dev Loss:0.2920328345149755
# Epoch 1: Dev Accuracy: 0.92109375 Dev Loss:0.23956600278615953
# Epoch 2: Dev Accuracy: 0.92421875 Dev Loss:0.27196917014662175
# Epoch 3: Dev Accuracy: 0.933984375 Dev Loss:0.2342769785784185
# Epoch 4: Dev Accuracy: 0.9359375 Dev Loss:0.2724121130420826
# Test Loss: 0.349 | Test Acc: 93.11%
# Test Prec: nan% | Test Rec: 20.927%
# currently training the model:  BGRU
# Epoch 0: Dev Accuracy: 0.924609375 Dev Loss:0.24588028294965625
# Epoch 1: Dev Accuracy: 0.93203125 Dev Loss:0.2224982707761228
# Epoch 2: Dev Accuracy: 0.94609375 Dev Loss:0.18224960272200405
# Epoch 3: Dev Accuracy: 0.9488372087478638 Dev Loss:0.16964999239426107
# Epoch 4: Dev Accuracy: 0.948046875 Dev Loss:0.17831069067469799
# Test Loss: 0.203 | Test Acc: 94.36%
# Test Prec: nan% | Test Rec: 37.755%
# currently training the model:  CNN
# Epoch 0: Dev Accuracy: 0.9121275439858436 Dev Loss:0.24632525108754635
# Epoch 1: Dev Accuracy: 0.9556686043739319 Dev Loss:0.22354797422594858
# Epoch 2: Dev Accuracy: 0.96953125 Dev Loss:0.1792174307783398
# Epoch 3: Dev Accuracy: 0.9607467293739319 Dev Loss:0.2239616980208666
# Epoch 4: Dev Accuracy: 0.96953125 Dev Loss:0.26012807146218647
# Test Loss: 0.315 | Test Acc: 95.78%
# Test Prec: nan% | Test Rec: 59.811%
# most effective words:  ['Factory', 'fashion', 'Girl', '\\n\\nIts', 'http://bit.ly/29qBUt7About', 'bay', 'UAS', 'https://twitter.com/SHO_Network\\nInstagram', 'http://foxs.pt/SkipBaylessTwitterFollow', 'maker']
# less effective words:  ['<pad>', 'blacksmithing', 'debt', 'NASCAR', 'allen', 'Kyla', 'Movies', 'Pranks', 'http://bit.ly/29kkemT\\n\\nLost', 'http://j.mp/1L0bVBu\\n\\nThe']

# %% [markdown]
# ### Run TFIDF with Machine Learning Models

# %%
tfidf_path = r'D:\Researching Data\Youtube data\tfidf' # should specify the directory for video data with TFIDF
TOPK = 5000
K = 500

# %%
new_TEXT, new_label, new_arr = data_in.get_tfidf_matrix(data_dir, 24, "full", TOPK)
X_train, y_train, X_valid, y_valid, X_test, y_test =\
data_in.split_reduced_data(tfidf_path, new_TEXT, new_label, 
                           K, TRAIN_VALID_TEST_R)
mlm_perform = mlm.ml_evaluate(mlm.CLFS, mlm.PARAMETER_DICT, X_train, y_train, 
                              X_valid, y_valid, X_test, y_test)
# Out:
# the current shape of the reduced data is  (6351, 5000)
# The size of train, valid and test data are 2540 2540 1271
# operation of random_forest method begins
# the best accuracy for method:  random_forest  is  0.8568056648308419
# the corresponding precision is :  0.9183673469387755
# the corresponding recall is :  0.4426229508196721
# operation of logistics method begins
# the best accuracy for method:  logistics  is  0.8426435877261998
# the corresponding precision is :  0.847682119205298
# the corresponding recall is :  0.419672131147541

# %% [markdown]
# ### Run N-Grams and BOW Classifiers

# %%
new_TEXT, new_label, new_arr = data_in.load_data(data_dir, 24, "full")
train_indices, valid_indices, test_indices = data_in.split_train_test(new_arr.shape[0], TRAIN_VALID_TEST_R)

X_train_bow = new_TEXT[train_indices]
y_train_bow = new_label[train_indices]
X_valid_bow = new_TEXT[valid_indices]
y_valid_bow = new_label[valid_indices]
X_test_bow = new_TEXT[test_indices]
y_test_bow = new_label[test_indices]

word_to_idx, wtorch = bowm.word_to_index(2, new_TEXT)
dgrams = bowm.word_ngrams(2, X_train_bow)[0]
VOCAB_SIZE = len(word_to_idx)
NUM_LABELS = 2
n = 2
# Out:
# 25.492048496299795  percent of videos are labelled as the selected category
# the baseline precision is  25.492048496299795  in this model
# The size of train, valid and test data are 2540 2540 1271

# %%
model = nnm.BoWNN(VOCAB_SIZE, NUM_LABELS)
perf_dict = bowm.run_bow_ngram(model, word_to_idx, wtorch, 
                               X_train_bow, y_train_bow, 
                               X_valid_bow, y_valid_bow, 
                               X_test_bow, y_test_bow, n)
# Out:
# For epoch number  0 , the accuracy for validation set is  0.8562992125984252
# For epoch number  1 , the accuracy for validation set is  0.8771653543307086
# For epoch number  2 , the accuracy for validation set is  0.8858267716535433
# For epoch number  3 , the accuracy for validation set is  0.8921259842519685
# For epoch number  4 , the accuracy for validation set is  0.8921259842519685
# the accuracy for test set is  0.8859166011014948
# the presision for test set is  0.8403908794788274
# the recall for test set is  0.7288135593220338

# %% [markdown]
# ### Performance Visualization

# %%
vis.alt.renderers.enable("notebook") # specify if you run it with local device
EPOCH = 5

# %%
full_perf_df, full_perf_df2, layer_perf_df = vis.process_perf_dict(models_perf, mlm_perform, perf_dict, EPOCH)
plt1 = vis.plot_nn_performance(full_perf_df)
plt2 = vis.plot_best_model(layer_perf_df)

# %%
plt1

# %%
plt2
